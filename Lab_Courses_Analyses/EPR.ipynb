# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import misc
import scipy.optimize as spo
import scipy.constants as constants
from scipy.constants import physical_constants as pc

# %%
### A)

# %%
data1=np.loadtxt('330-339')
data2=np.loadtxt('330-339_101')
data5=np.loadtxt('3327-3351_226')
data6=np.loadtxt('3327-3351_448')
data7=np.loadtxt('3327-3351_616')
data3=np.loadtxt('3330-3351_119')
data4=np.loadtxt('3330-3351_130')
data8=np.loadtxt('3330-3351_912')

# %%
#plt.plot(data8.T[0],data8.T[1],label='zero')
#plt.plot(data7.T[0],data7.T[1],label='prime')
#plt.plot(data6.T[0],data6.T[1],label='second')
#plt.plot(data5.T[0],data5.T[1],label='third')
#plt.plot(data4.T[0],data4.T[1],label='prime')
#plt.plot(data3.T[0],data3.T[1],label='prime')
#plt.plot(data2.T[0],data2.T[1],label='prime')
X=[333.86258,334.08306]
Y=[-0.08072,0.04412]
plt.plot(data1.T[0],data1.T[1],label=r'$A_{lock-in}=minimum$')
plt.plot(333.9728,0,marker='o',linestyle = 'None',label=r'$B_{res}=(333,98\pm0,01)mT$')
plt.plot(X,Y,marker='*',color='red',linestyle = 'None',label=r'$FWHM=(0,220\pm0,014)mT$')
plt.grid()
plt.xlabel('B-Field [mT]',fontsize=16)
plt.ylabel('intensity [a.u.]',fontsize=16)
plt.legend(loc='lower right',fontsize=10)
plt.savefig("DPPH_spectr.pdf",bbox_inches="tight",pad_inches=0.05)
plt.show()
print(pc["Bohr magneton in Hz/T"])
print(pc["Bohr magneton in Hz/T"][0])
print(9.3661*(10**9)/(pc["Bohr magneton in Hz/T"][0]*0.33398))
print(((-9.3661*(10**9)*0.00001/(0.33398*pc["Bohr magneton in Hz/T"][0]**2))**2 +(0.0014*(10**9)/(0.33398*pc["Bohr magneton in Hz/T"][0]))**2)**(0.5))
# Out:
# (13996245042.0, 'Hz T^-1', 86.0)
# 13996245042.0
# 2.0036727536455943
# 0.00029949945602799797
